# %%
# Reading all csv files in the directory
import os
import pandas as pd

brent = pd.read_csv('brent_filtered.csv',index_col = False, header=0) # daily
eu_capitalflows = pd.read_csv('eu_capitalflows.csv', index_col=False, header=0, sep=';') # monthly
eu_consumer_confidence_index = pd.read_csv('eu_consumer_confidence_index.csv', index_col=False, header=0, sep = ';') # monthly
eu_cpi = pd.read_csv('eu_cpi.csv', index_col=False, header=0, sep = ';') # monthly
eu_ecb_assets = pd.read_csv('eu_ecb_assets.csv', index_col=False, header=0, sep = ';') # quarterly
eu_eur_stoxx_vix = pd.read_csv('eu_eur_stoxx_vix.csv', index_col=False, header=0, sep = ';') # daily
eu_eur_stoxx = pd.read_csv('eu_eur_stoxx.csv', index_col=False, header=0) # daily
eu_gdp = pd.read_csv('eu_gdp.csv', index_col=False, header=0) # quarterly
eu_m2 = pd.read_csv('eu_m2.csv', index_col=False, header=0, sep = ';') # monthly
eu_mro_rate = pd.read_csv('eu_mro_rate.csv', index_col=False, header=0, sep = ';') # daily
eu_trade_balance = pd.read_csv('eu_trade_balance.csv', index_col=False, header=0, sep = ';') # quarterly
eu_unemployment_rate = pd.read_csv('eu_unemployment_rate.csv', index_col=False, header=0, sep = ';') #  monthly
eu_wage = pd.read_csv('eu_wage.csv', index_col=False, header=0) # quarterly
eu_yield_3m = pd.read_csv('eu_yield_3m.csv', index_col=False, header=0, sep = ';') # daily
eu_yield_10y = pd.read_csv('eu_yield_10y.csv', index_col=False, header=0, sep = ';') # daily
eu_yield_30y = pd.read_csv('eu_yield_30y.csv', index_col=False, header=0, sep = ';') # daily

us_capitalflows = pd.read_csv('us_capitalflows.csv', index_col=False, header=0, sep = ';') # monthly
us_consumer_confidence_index = pd.read_csv('us_consumer_confidence_index.csv', index_col=False, header=0, sep = ';') # monthly
us_cpi = pd.read_csv('us_cpi.csv', index_col=False, header=0) # monthly
us_federal_funds_rate = pd.read_csv('us_federal_funds_rate_filtered.csv', index_col=False, header=0) # daily
us_fred_assets = pd.read_csv('us_fred_assets.csv', index_col=False, header=0, sep = ';') # weekly
us_m2 = pd.read_csv('us_m2.csv', index_col=False, header=0, sep = ';') # weekly
us_readl_gdp = pd.read_csv('us_real_gdp_filtered.csv', index_col=False, header=0) # quarterly
us_sp_500_vix = pd.read_csv('us_sp_500_vix.csv', index_col=False, header=0) # daily
us_sp500 = pd.read_csv('us_sp500_filtered.csv', index_col=False, header=0, sep = ';') # daily
us_trade_balance = pd.read_csv('us_trade_balance.csv', index_col=False, header=0, sep = ';') # monthly
us_treasury_yield_3m = pd.read_csv('us_treasury_yield_3m_filtered.csv', index_col=False, header=0) # daily
us_treasury_yield_10y = pd.read_csv('us_treasury_yield_10y_filtered.csv', index_col=False, header=0) # daily
us_treasury_yield_30y = pd.read_csv('us_treasury_yield_30y_filtered.csv', index_col=False, header=0) # daily
us_unemployment_rate = pd.read_csv('us_unemployment_filtered.csv', index_col=False, header=0) # monthly

usd_eur_exchange = pd.read_csv('usd_eur_exchange.csv', index_col=False, header=0) # daily

# %%
# Printing lenth of each dataframe
print('brent:', len(brent))
print('eu_capitalflows:', len(eu_capitalflows))
print('eu_consumer_confidence_index:', len(eu_consumer_confidence_index))
print('eu_cpi:', len(eu_cpi))
print('eu_ecb_assets:', len(eu_ecb_assets))
print('eu_eur_stoxx_vix:', len(eu_eur_stoxx_vix))
print('eu_eur_stoxx:', len(eu_eur_stoxx))
print('eu_gdp:', len(eu_gdp))
print('eu_m2:', len(eu_m2))
print('eu_mro_rate:', len(eu_mro_rate))
print('eu_trade_balance:', len(eu_trade_balance))
print('eu_unemployment_rate:', len(eu_unemployment_rate))
print('eu_wage:', len(eu_wage))
print('eu_yield_3m:', len(eu_yield_3m))
print('eu_yield_10y:', len(eu_yield_10y))
print('eu_yield_30y:', len(eu_yield_30y))

print('us_capitalflows:', len(us_capitalflows))
print('us_consumer_confidence_index:', len(us_consumer_confidence_index))
print('us_cpi:', len(us_cpi))
print('us_federal_funds_rate:', len(us_federal_funds_rate))
print('us_fred_assets:', len(us_fred_assets))
print('us_m2:', len(us_m2))
print('us_readl_gdp:', len(us_readl_gdp))
print('us_sp_500_vix:', len(us_sp_500_vix))
print('us_sp500:', len(us_sp500))
print('us_trade_balance:', len(us_trade_balance))
print('us_treasury_yield_3m:', len(us_treasury_yield_3m))
print('us_treasury_yield_10y:', len(us_treasury_yield_10y))
print('us_treasury_yield_30y:', len(us_treasury_yield_30y))
print('us_unemployment_rate:', len(us_unemployment_rate))

print('usd_eur_exchange:', len(usd_eur_exchange))
# Out:
# brent: 5215
# eu_capitalflows: 242
# eu_consumer_confidence_index: 239
# eu_cpi: 241
# eu_ecb_assets: 93
# eu_eur_stoxx_vix: 6461
# eu_eur_stoxx: 6208
# eu_gdp: 80
# eu_m2: 242
# eu_mro_rate: 9271
# eu_trade_balance: 132
# eu_unemployment_rate: 241
# eu_wage: 111
# eu_yield_3m: 5035
# eu_yield_10y: 5035
# eu_yield_30y: 5035
# us_capitalflows: 241
# us_consumer_confidence_index: 239
# us_cpi: 291
# us_federal_funds_rate: 7303
# us_fred_assets: 1118
# us_m2: 241
# us_readl_gdp: 79
# us_sp_500_vix: 8670
# us_sp500: 5034
# us_trade_balance: 80
# us_treasury_yield_3m: 5217
# us_treasury_yield_10y: 5217
# us_treasury_yield_30y: 5217
# us_unemployment_rate: 239
# usd_eur_exchange: 6615

# %%
# Convert all date columns to datetime
brent['Date'] = pd.to_datetime(brent['date'])
eu_capitalflows['Date'] = pd.to_datetime(eu_capitalflows['date'])
eu_consumer_confidence_index['Date'] = pd.to_datetime(eu_consumer_confidence_index['DATE'])
eu_cpi['Date'] = pd.to_datetime(eu_cpi['TIME_PERIOD'])
eu_ecb_assets['Date'] = pd.to_datetime(eu_ecb_assets['DATE'])
eu_eur_stoxx_vix['Date'] = pd.to_datetime(eu_eur_stoxx_vix['Date'], format='%d/%m/%Y')
eu_eur_stoxx['Date'] = pd.to_datetime(eu_eur_stoxx['Date'], format = '%d/%m/%Y %H.%M.%S')
eu_gdp['Date'] = pd.to_datetime(eu_gdp['DATE'])
eu_m2['Date'] = pd.to_datetime(eu_m2['DATE'])
eu_mro_rate['Date'] = pd.to_datetime(eu_mro_rate['DATE'])
eu_trade_balance['Date'] = pd.to_datetime(eu_trade_balance['TIME_PERIOD'])
eu_unemployment_rate['Date'] = pd.to_datetime(eu_unemployment_rate['TIME_PERIOD'])
eu_wage['Date'] = pd.to_datetime(eu_wage['DATE'])
eu_yield_3m['Date'] = pd.to_datetime(eu_yield_3m['DATE'])
eu_yield_10y['Date'] = pd.to_datetime(eu_yield_10y['DATE'])
eu_yield_30y['Date'] = pd.to_datetime(eu_yield_30y['DATE'])

us_capitalflows['Date'] = pd.to_datetime(us_capitalflows['date'])
us_consumer_confidence_index['Date'] = pd.to_datetime(us_consumer_confidence_index['DATE'])
us_cpi['Date'] = pd.to_datetime(us_cpi['DATE'])
us_federal_funds_rate['Date'] = pd.to_datetime(us_federal_funds_rate['date'])
us_fred_assets['Date'] = pd.to_datetime(us_fred_assets['DATE'])
us_m2['Date'] = pd.to_datetime(us_m2['DATE'])
us_readl_gdp['Date'] = pd.to_datetime(us_readl_gdp['date'])
us_sp_500_vix['Date'] = pd.to_datetime(us_sp_500_vix['DATE'])
us_sp500['Date'] = pd.to_datetime(us_sp500['Date'])
us_trade_balance['Date'] = pd.to_datetime(us_trade_balance['DATE'])
us_treasury_yield_3m['Date'] = pd.to_datetime(us_treasury_yield_3m['date'])
us_treasury_yield_10y['Date'] = pd.to_datetime(us_treasury_yield_10y['date'])
us_treasury_yield_30y['Date'] = pd.to_datetime(us_treasury_yield_30y['date'])
us_unemployment_rate['Date'] = pd.to_datetime(us_unemployment_rate['date'])

usd_eur_exchange['Date'] = pd.to_datetime(usd_eur_exchange['DATE'])
# Out:
# /var/folders/wc/2m3d8lq52l31bmr5kx32jxzh0000gn/T/ipykernel_27430/3963648229.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   eu_trade_balance['Date'] = pd.to_datetime(eu_trade_balance['TIME_PERIOD'])

# %%
# printing max and min date of each dataframe
print('brent:', brent['Date'].min(), brent['Date'].max())
print('eu_capitalflows:', eu_capitalflows['Date'].min(), eu_capitalflows['Date'].max())
print('eu_consumer_confidence_index:', eu_consumer_confidence_index['Date'].min(), eu_consumer_confidence_index['Date'].max())
print('eu_cpi:', eu_cpi['Date'].min(), eu_cpi['Date'].max())
print('eu_ecb_assets:', eu_ecb_assets['Date'].min(), eu_ecb_assets['Date'].max())
print('eu_eur_stoxx_vix:', eu_eur_stoxx_vix['Date'].min(), eu_eur_stoxx_vix['Date'].max())
print('eu_eur_stoxx:', eu_eur_stoxx['Date'].min(), eu_eur_stoxx['Date'].max())
print('eu_gdp:', eu_gdp['Date'].min(), eu_gdp['Date'].max())
print('eu_m2:', eu_m2['Date'].min(), eu_m2['Date'].max())
print('eu_mro_rate:', eu_mro_rate['Date'].min(), eu_mro_rate['DATE'].max())
print('eu_trade_balance:', eu_trade_balance['Date'].min(), eu_trade_balance['Date'].max())
print('eu_unemployment_rate:', eu_unemployment_rate['Date'].min(), eu_unemployment_rate['Date'].max())
print('eu_wage:', eu_wage['Date'].min(), eu_wage['Date'].max())
print('eu_yield_3m:', eu_yield_3m['Date'].min(), eu_yield_3m['Date'].max())
print('eu_yield_10y:', eu_yield_10y['Date'].min(), eu_yield_10y['Date'].max())
print('eu_yield_30y:', eu_yield_30y['Date'].min(), eu_yield_30y['Date'].max())

print('us_capitalflows:', us_capitalflows['Date'].min(), us_capitalflows['Date'].max())
print('us_consumer_confidence_index:', us_consumer_confidence_index['Date'].min(), us_consumer_confidence_index['Date'].max())
print('us_cpi:', us_cpi['Date'].min(), us_cpi['Date'].max())
print('us_federal_funds_rate:', us_federal_funds_rate['Date'].min(), us_federal_funds_rate['Date'].max())
print('us_fred_assets:', us_fred_assets['Date'].min(), us_fred_assets['Date'].max())
print('us_m2:', us_m2['Date'].min(), us_m2['Date'].max())
print('us_readl_gdp:', us_readl_gdp['Date'].min(), us_readl_gdp['Date'].max())
print('us_sp_500_vix:', us_sp_500_vix['Date'].min(), us_sp_500_vix['Date'].max())
print('us_sp500:', us_sp500['Date'].min(), us_sp500['Date'].max())
print('us_trade_balance:', us_trade_balance['Date'].min(), us_trade_balance['Date'].max())
print('us_treasury_yield_3m:', us_treasury_yield_3m['Date'].min(), us_treasury_yield_3m['Date'].max())
print('us_treasury_yield_10y:', us_treasury_yield_10y['Date'].min(), us_treasury_yield_10y['Date'].max())
print('us_treasury_yield_30y:', us_treasury_yield_30y['Date'].min(), us_treasury_yield_30y['Date'].max())
print('us_unemployment_rate:', us_unemployment_rate['Date'].min(), us_unemployment_rate['Date'].max())

print('usd_eur_exchange:', usd_eur_exchange['Date'].min(), usd_eur_exchange['Date'].max())
# Out:
# brent: 2004-05-18 00:00:00 2024-05-13 00:00:00
# eu_capitalflows: 2004-01-01 00:00:00 2024-01-02 00:00:00
# eu_consumer_confidence_index: 2004-03-01 00:00:00 2024-01-01 00:00:00
# eu_cpi: 2004-03-01 00:00:00 2024-03-01 00:00:00
# eu_ecb_assets: 2000-12-31 00:00:00 2023-12-31 00:00:00
# eu_eur_stoxx_vix: 1999-01-04 00:00:00 2024-05-17 00:00:00
# eu_eur_stoxx: 2000-01-03 18:00:00 2024-05-16 18:00:00
# eu_gdp: 2004-01-01 00:00:00 2023-10-01 00:00:00
# eu_m2: 2004-02-29 00:00:00 2024-03-31 00:00:00
# eu_mro_rate: 1999-01-01 00:00:00 2024-05-19
# eu_trade_balance: 2013-01-01 00:00:00 2023-10-01 00:00:00
# eu_unemployment_rate: 2004-03-01 00:00:00 2024-03-01 00:00:00
# eu_wage: 1996-01-01 00:00:00 2023-07-01 00:00:00
# eu_yield_3m: 2004-09-06 00:00:00 2024-05-16 00:00:00
# eu_yield_10y: 2004-09-06 00:00:00 2024-05-16 00:00:00
# eu_yield_30y: 2004-09-06 00:00:00 2024-05-16 00:00:00
# us_capitalflows: 2004-01-01 00:00:00 2024-01-01 00:00:00
# ...

# %%
# plotting exchange rate
import matplotlib.pyplot as plt
# Out:
# Error in callback <function flush_figures at 0x166812ca0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...
